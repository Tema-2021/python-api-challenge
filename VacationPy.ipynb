# %% [markdown]
# # VacationPy
# ----
#
# #### Note
# * Keep an eye on your API usage. Use https://developers.google.com/maps/reporting/gmp-reporting as reference for how to monitor your usage and billing.
#
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import gmaps
import os

# Import API key
from api_keys import g_key

# %% [markdown]
# ### Store Part I results into DataFrame
# * Load the csv exported in Part I to a DataFrame

# %%
os.getcwd()
# Out:
# 'C:\\Users\\vaab2\\OneDrive\\Desktop\\DataAnalyticsBootcamp\\02-Homework\\06-Python-APIs\\Instructions\\starter_code'

# %%
output_data_file = os.path.join(os.getcwd(), 'weather.csv')
city_weather_df = pd.read_csv(output_data_file)
city_weather_df.head()
# Out:
#    City_ID       City  Cloudiness Country        Date  Humidity    Lat  \
# 0        0  ostrovnoy           2      RU  1558378754        72  68.05
# 1        1  mahebourg          75      MU  1558378503        74 -20.41
# 2        2    qaanaaq          25      GL  1558378755        73  77.48
# 3        3     zhuhai           0      CN  1558378755        39  40.71
# 4        4  cape town          20      ZA  1558378755        76 -33.93
#
#       Lng  Max Temp  Wind Speed
# 0   39.51     37.50        7.16
# 1   57.70     78.80       11.41
# 2  -69.36     22.20        2.37
# 3  112.04     44.60        4.47
# 4   18.42     55.99        8.05

# %% [markdown]
# ### Humidity Heatmap
# * Configure gmaps.
# * Use the Lat and Lng as locations and Humidity as the weight.
# * Add Heatmap layer to map.

# %%
# Access maps with unique API key
gmaps.configure(api_key=g_key)

# %%
# Use the Lat and Lng as locations and Humidity as the weight
locations = city_weather_df[["Lat", "Lng"]]

humidity = city_weather_df["Humidity"]

# %%
# Add Heatmap layer to map
figure_layout = {
    'width': '400px',
    'height': '300px',
    'borde': '01px solid black',
    'padding': '1px',
    'margin': '0 auto 0 auto',
    'weights': humidity,
    'dissipating': False,
    'max_intensity': max(humidity),
    'point_radius': 3,
    'center': (46.0, -5.0),
    'zoom_level': 2
}

fig = gmaps.figure(layout=figure_layout)

# %%
# Assign the marker layer to a variable
#markers = gmaps.figure(locations)| gmaps.figure(humidity).empty
# Add the layer to the map
#fig.add_layer(markers)
fig
# Out:
# Figure(layout=FigureLayout(height='300px', margin='0 auto 0 auto', padding='1px', width='400px'))

# %% [markdown]
# ### Create new DataFrame fitting weather criteria
# * Narrow down the cities to fit weather conditions.
# * Drop any rows will null values.

# %%
max_temp_df = city_weather_df.loc[city_weather_df['Max Temp'] < 80]
max_temp_df
# Out:
#      City_ID         City  Cloudiness Country        Date  Humidity    Lat  \
# 0          0    ostrovnoy           2      RU  1558378754        72  68.05
# 1          1    mahebourg          75      MU  1558378503        74 -20.41
# 2          2      qaanaaq          25      GL  1558378755        73  77.48
# 3          3       zhuhai           0      CN  1558378755        39  40.71
# 4          4    cape town          20      ZA  1558378755        76 -33.93
# ..       ...          ...         ...     ...         ...       ...    ...
# 541      541     tamworth          64      AU  1558378897        87 -31.09
# 542      542        perth          20      GB  1558378872        82  56.40
# 545      545      veraval           0      FR  1558378898        62  49.65
# 546      546  novyy urgal         100      RU  1558378899        93  51.07
# 547      547      tongren           4      CN  1558378899        64  27.72
#
#         Lng  Max Temp  Wind Speed
# ...

# %%
max_temp1_df = max_temp_df.loc[max_temp_df['Max Temp'] > 70]
max_temp1_df
# Out:
#      City_ID             City  Cloudiness Country        Date  Humidity  \
# 1          1        mahebourg          75      MU  1558378503        74
# 7          7            opuwo           0     NaN  1558378523        23
# 12        12           avarua         100      CK  1558378756        94
# 18        18  bambous virieux          75      MU  1558378758        74
# 25        25          kantang          20      TH  1558378759        94
# ..       ...              ...         ...     ...         ...       ...
# 516      516          malindi          75      KE  1558378808        88
# 521      521        high rock          75      BS  1558378893        83
# 530      530           hirara          37      JP  1558378895        67
# 534      534           marzuq          84      YE  1558378896        36
# 539      539             palu          72      ID  1558378897        80
#
#        Lat     Lng  Max Temp  Wind Speed
# 1   -20.41   57.70     78.80       11.41
# ...

# %%
wind_speed_df = max_temp1_df.loc[max_temp1_df['Wind Speed'] < 10]
wind_speed_df
# Out:
#      City_ID                  City  Cloudiness Country        Date  Humidity  \
# 7          7                 opuwo           0     NaN  1558378523        23
# 12        12                avarua         100      CK  1558378756        94
# 25        25               kantang          20      TH  1558378759        94
# 44        44          puerto ayora          26      EC  1558378762        86
# 59        59               bontang          54      ID  1558378765        99
# 70        70          ponta do sol           0      BR  1558378767        57
# 87        87              ambilobe           2      MG  1558378770        92
# 88        88              cidreira           0      BR  1558378770        66
# 91        91           bella vista          62      AR  1558378771        80
# 100      100                sorong          95      ID  1558378773        93
# 104      104                mbigou          70      GA  1558378773        94
# ...

# %%
cloud_df = wind_speed_df.loc[wind_speed_df['Cloudiness'] == 0]
cloud_df
# Out:
#      City_ID          City  Cloudiness Country        Date  Humidity    Lat  \
# 7          7         opuwo           0     NaN  1558378523        23 -18.06
# 70        70  ponta do sol           0      BR  1558378767        57 -20.63
# 88        88      cidreira           0      BR  1558378770        66 -30.17
# 138      138     morondava           0      MG  1558378780        69 -20.30
# 139      139         vaini           0      IN  1558378780        88  15.34
# 176      176         nador           0      MA  1558378499        40  35.17
# 297      297         mogok           0      MM  1558378844        51  22.92
# 444      444       birjand           0      IR  1558378880        26  32.86
#
#        Lng  Max Temp  Wind Speed
# 7    13.84     72.06        5.44
# 70  -46.00     73.68        5.32
# 88  -50.22     76.56        5.50
# 138  44.28     79.08        9.06
# 139  74.49     78.90        1.59
# 176  -2.93     75.20        6.93
# 297  96.51     72.24        2.77
# ...

# %%
narrow_down_df = cloud_df.dropna()
narrow_down_df
# Out:
#      City_ID          City  Cloudiness Country        Date  Humidity    Lat  \
# 70        70  ponta do sol           0      BR  1558378767        57 -20.63
# 88        88      cidreira           0      BR  1558378770        66 -30.17
# 138      138     morondava           0      MG  1558378780        69 -20.30
# 139      139         vaini           0      IN  1558378780        88  15.34
# 176      176         nador           0      MA  1558378499        40  35.17
# 297      297         mogok           0      MM  1558378844        51  22.92
# 444      444       birjand           0      IR  1558378880        26  32.86
#
#        Lng  Max Temp  Wind Speed
# 70  -46.00     73.68        5.32
# 88  -50.22     76.56        5.50
# 138  44.28     79.08        9.06
# 139  74.49     78.90        1.59
# 176  -2.93     75.20        6.93
# 297  96.51     72.24        2.77
# 444  59.22     71.60        9.17

# %% [markdown]
# ### Hotel Map
# * Store into variable named `hotel_df`.
# * Add a "Hotel Name" column to the DataFrame.
# * Set parameters to search for hotels with 5000 meters.
# * Hit the Google Places API for each city's coordinates.
# * Store the first Hotel result into the DataFrame.
# * Plot markers on top of the heatmap.

# %%
hotel_df = narrow_down_df.loc[:,['City', 'Cloudiness', 'Country', 'Date', 'Humidity', 'Lat', 'Lng', 'Max Temp', 'Wind Speed']]
hotel_df
# Out:
#              City  Cloudiness Country        Date  Humidity    Lat    Lng  \
# 70   ponta do sol           0      BR  1558378767        57 -20.63 -46.00
# 88       cidreira           0      BR  1558378770        66 -30.17 -50.22
# 138     morondava           0      MG  1558378780        69 -20.30  44.28
# 139         vaini           0      IN  1558378780        88  15.34  74.49
# 176         nador           0      MA  1558378499        40  35.17  -2.93
# 297         mogok           0      MM  1558378844        51  22.92  96.51
# 444       birjand           0      IR  1558378880        26  32.86  59.22
#
#      Max Temp  Wind Speed
# 70      73.68        5.32
# 88      76.56        5.50
# 138     79.08        9.06
# 139     78.90        1.59
# 176     75.20        6.93
# 297     72.24        2.77
# 444     71.60        9.17

# %%
hotel_df['Hotel Name'] = ""
hotel_df
# Out:
#              City  Cloudiness Country        Date  Humidity    Lat    Lng  \
# 70   ponta do sol           0      BR  1558378767        57 -20.63 -46.00
# 88       cidreira           0      BR  1558378770        66 -30.17 -50.22
# 138     morondava           0      MG  1558378780        69 -20.30  44.28
# 139         vaini           0      IN  1558378780        88  15.34  74.49
# 176         nador           0      MA  1558378499        40  35.17  -2.93
# 297         mogok           0      MM  1558378844        51  22.92  96.51
# 444       birjand           0      IR  1558378880        26  32.86  59.22
#
#      Max Temp  Wind Speed Hotel Name
# 70      73.68        5.32
# 88      76.56        5.50
# 138     79.08        9.06
# 139     78.90        1.59
# 176     75.20        6.93
# 297     72.24        2.77
# 444     71.60        9.17

# %%
import json
base_url = "https://maps.googleapis.com/maps/api/place/nearbysearch/json"
city_coord = f"{lat},{lng}"
params = {"type" : "hotel",
          "location" : "city_coord",
          "radius" : 5000,
          "key" : g_key}

# %%
# use iterrows to iterate through pandas dataframe
for index, row in hotel_df.iterrows():
    lat = row["Lat"]
    lng = row["Lng"]
    city_name = row["City"]
    
    # get hotel name from df
    #hotel_name = row['Hotel Name']
    hotel_name = row['City']
    
    # add keyword to params dict
    params['keyword'] = hotel_name
    
     # assemble url and make API request
    print(f"First Hotel {index}: {city_name}.")
    response = requests.get(base_url, params=params).json()
    
     # extract results
    results = response['results']
    
    try:
        print(f"The first hotel in {city_name} is {results[0]['city_name']}.")
        hotel_df.loc[index, 'city_name'] = results[0]['name']
        
    except (KeyError, IndexError):
        print("First hotel not found......")
# Out:
# First Hotel 70: ponta do sol.
# First hotel not found......
# First Hotel 88: cidreira.
# First hotel not found......
# First Hotel 138: morondava.
# First hotel not found......
# First Hotel 139: vaini.
# First hotel not found......
# First Hotel 176: nador.
# First hotel not found......
# First Hotel 297: mogok.
# First hotel not found......
# First Hotel 444: birjand.
# First hotel not found......

# %%
# NOTE: Do not change any of the code in this cell

# Using the template add the hotel marks to the heatmap
info_box_template = """
<dl>
<dt>Name</dt><dd>{Hotel Name}</dd>
<dt>City</dt><dd>{City}</dd>
<dt>Country</dt><dd>{Country}</dd>
</dl>
"""
# Store the DataFrame Row
# NOTE: be sure to update with your DataFrame name
hotel_info = [info_box_template.format(**row) for index, row in hotel_df.iterrows()]
locations = hotel_df[["Lat", "Lng"]]

# %%
# Add marker layer ontop of heat map
# Add marker layer ontop of heat map
markers = gmaps.marker_layer(locations, info_box_content = hotel_info)
fig.add_layer(markers)

# Display figure
fig
# Out:
# Figure(layout=FigureLayout(height='300px', margin='0 auto 0 auto', padding='1px', width='400px'))

# %%
hotel_df
# Out:
#              City  Cloudiness Country        Date  Humidity    Lat    Lng  \
# 70   ponta do sol           0      BR  1558378767        57 -20.63 -46.00
# 88       cidreira           0      BR  1558378770        66 -30.17 -50.22
# 138     morondava           0      MG  1558378780        69 -20.30  44.28
# 139         vaini           0      IN  1558378780        88  15.34  74.49
# 176         nador           0      MA  1558378499        40  35.17  -2.93
# 297         mogok           0      MM  1558378844        51  22.92  96.51
# 444       birjand           0      IR  1558378880        26  32.86  59.22
#
#      Max Temp  Wind Speed Hotel Name
# 70      73.68        5.32
# 88      76.56        5.50
# 138     79.08        9.06
# 139     78.90        1.59
# 176     75.20        6.93
# 297     72.24        2.77
# 444     71.60        9.17
